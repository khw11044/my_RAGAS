# %%
import pandas as pd 
import ast
import nest_asyncio         # nest_asyncio는 파이썬의 비동기 코드 실행을 도와주는 패키지
nest_asyncio.apply()        # Jupyter 노트북과 같이 이벤트 루프가 이미 실행 중인 환경에서 비동기 코드를 여러 번 실행할 수 있도록 설정하는 데 사용
# 이거 안하면 무조건 에러남 
import os

# %%
base_dir = 'experiment_dataset/QA_results'

# %%
path = os.path.join(base_dir, 'setting1_retriever1.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting1_retriever1_003
# 0.4459992478328868
#                      index  faithfulness  answer_relevancy  \
# 0  setting1_retriever1_003      0.557778          0.489776
# 1  setting1_retriever1_005      0.277778          0.392770
# 2  setting1_retriever1_007      0.498095          0.384205
# 3  setting1_retriever1_010      0.518519          0.188469
#
#    answer_correctness  context_recall  context_precision      mean
# 0            0.332443        0.200000           0.650000  0.445999
# 1            0.344740        0.300000           0.690556  0.401169
# 2            0.379663        0.300000           0.617341  0.435861
# 3            0.351572        0.388889           0.625664  0.414623

# %%
path = os.path.join(base_dir, 'setting2_retriever2.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting2_retriever2_005
# 0.4842917732461468
#                      index  faithfulness  answer_relevancy  \
# 0  setting2_retriever2_003      0.461699          0.488413
# 1  setting2_retriever2_005      0.388624          0.584491
# 2  setting2_retriever2_007      0.493056          0.577732
# 3  setting2_retriever2_010      0.625000          0.378666
#
#    answer_correctness  context_recall  context_precision      mean
# 0            0.377002            0.35           0.633333  0.462089
# 1            0.471121            0.30           0.677222  0.484292
# 2            0.402009            0.20           0.575774  0.449714
# 3            0.362732            0.30           0.649123  0.463104

# %%
path = os.path.join(base_dir, 'setting3_retriever3.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting3_retriever3_007_001
# 0.5067771735029548
#                           index  faithfulness  answer_relevancy  \
# 0   setting3_retriever3_003_001      0.531973          0.295619
# 1   setting3_retriever3_003_002      0.374644          0.387866
# 2   setting3_retriever3_003_003      0.390476          0.485321
# 3   setting3_retriever3_003_004      0.392593          0.391004
# 4   setting3_retriever3_003_005      0.370370          0.391552
# 5   setting3_retriever3_003_006      0.477778          0.489182
# 6   setting3_retriever3_003_007      0.483631          0.393874
# 7   setting3_retriever3_005_001      0.481481          0.295933
# 8   setting3_retriever3_005_002      0.564815          0.474562
# 9   setting3_retriever3_005_003      0.455222          0.382097
# 10  setting3_retriever3_005_004      0.354167          0.486580
# 11  setting3_retriever3_005_005      0.512346          0.590953
# 12  setting3_retriever3_005_006      0.666667          0.488369
# 13  setting3_retriever3_005_007      0.487879          0.492174
# 14  setting3_retriever3_007_001      0.611310          0.584722
# 15  setting3_retriever3_007_002      0.443020          0.490705
# 16  setting3_retriever3_007_003      0.368421          0.581053
# 17  setting3_retriever3_007_004      0.453704          0.585943
# 18  setting3_retriever3_007_005      0.354167          0.487358
# 19  setting3_retriever3_007_006      0.481481          0.392289
# 20  setting3_retriever3_007_007      0.388889          0.291462
# 21  setting3_retriever3_010_001      0.666667          0.383109
# 22  setting3_retriever3_010_002      0.402778          0.388520
# 23  setting3_retriever3_010_003      0.583333          0.280527
# 24  setting3_retriever3_010_004      0.511574          0.378289
# 25  setting3_retriever3_010_005      0.483165          0.381280
# 26  setting3_retriever3_010_006      0.510417          0.486897
# 27  setting3_retriever3_010_007      0.611111          0.380715
#
#     answer_correctness  context_recall  context_precision      mean
# 0             0.422191        0.444444           0.550000  0.448845
# 1             0.433071        0.300000           0.533333  0.405783
# 2             0.426977        0.300000           0.650000  0.450555
# 3             0.400959        0.300000           0.550000  0.406911
# 4             0.352391        0.400000           0.733333  0.449529
# 5             0.396169        0.300000           0.708333  0.474292
# 6             0.448197        0.200000           0.641667  0.433474
# 7             0.432773        0.300000           0.653750  0.432787
# 8             0.406899        0.300000           0.657083  0.480672
# 9             0.368374        0.250000           0.665417  0.424222
# 10            0.432447        0.300000           0.663750  0.447389
# 11            0.384890        0.300000           0.674444  0.492527
# 12            0.412331        0.300000           0.632639  0.500001
# 13            0.373942        0.300000           0.631667  0.457132
# 14            0.347517        0.300000           0.690337  0.506777
# 15            0.468316        0.250000           0.644663  0.459341
# 16            0.412094        0.300000           0.593413  0.450996
# 17            0.473226        0.300000           0.626310  0.487836
# 18            0.425398        0.200000           0.621393  0.417663
# 19            0.395663        0.200000           0.605302  0.414947
# 20            0.454911        0.250000           0.575516  0.392156
# 21            0.359968        0.300000           0.567150  0.455379
# 22            0.450696        0.350000           0.604146  0.439228
# 23            0.390459        0.250000           0.592600  0.419384
# 24            0.455031        0.300000           0.602315  0.449442
# 25            0.347607        0.300000           0.569281  0.416267
# 26            0.444558        0.250000           0.587549  0.455884
# 27            0.408743        0.250000           0.618052  0.453724

# %%
path = os.path.join(base_dir, 'setting4_our_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 4
#       1 path = os.path.join(base_dir, 'setting4_our_retriever.xlsx')
#       3 # make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음
# ----> 4 df = pd.read_excel(path)
#       6 max_mean_index = df.loc[df['mean'].idxmax(), 'index']
#       8 print(max_mean_index)
#
# File c:\Users\kim_h\anaconda3\envs\AUTORAG\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\kim_h\anaconda3\envs\AUTORAG\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\kim_h\anaconda3\envs\AUTORAG\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\kim_h\anaconda3\envs\AUTORAG\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiment_dataset/QA_results\\setting4_our_retriever.xlsx'

# %%
path = os.path.join(base_dir, 'setting5_mq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting5_mq_retriever
# 0.383645597928128
#                    index  faithfulness  answer_relevancy  answer_correctness  \
# 0  setting5_mq_retriever      0.256614          0.277711            0.413804
#
#    context_recall  context_precision      mean
# 0             0.3           0.670099  0.383646

# %%
path = os.path.join(base_dir, 'setting6_sq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting6_sq_retriever
# 0.3847140693546268
#                    index  faithfulness  answer_relevancy  answer_correctness  \
# 0  setting6_sq_retriever      0.290741          0.679777            0.383608
#
#    context_recall  context_precision      mean
# 0        0.111111           0.458333  0.384714
