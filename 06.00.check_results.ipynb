# %%
import pandas as pd 
import ast
import nest_asyncio         # nest_asyncio는 파이썬의 비동기 코드 실행을 도와주는 패키지
nest_asyncio.apply()        # Jupyter 노트북과 같이 이벤트 루프가 이미 실행 중인 환경에서 비동기 코드를 여러 번 실행할 수 있도록 설정하는 데 사용
# 이거 안하면 무조건 에러남 
import os

# %%
base_dir = 'experiment_dataset/QA_chatgpt_35_results'

# %%
path = os.path.join(base_dir, 'setting1_retriever1.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting1_retriever1_010
# 0.530165964268122
#                      index  faithfulness  answer_relevancy  \
# 0  setting1_retriever1_003      0.270833          0.669356
# 1  setting1_retriever1_005      0.295455          0.373837
# 2  setting1_retriever1_007      0.416667          0.471484
# 3  setting1_retriever1_010      0.640212          0.566728
#
#    answer_correctness  context_recall  context_precision      mean
# 0            0.341536            0.20           0.650000  0.426345
# 1            0.369975            0.20           0.660556  0.379964
# 2            0.406355            0.30           0.685028  0.455907
# 3            0.445484            0.35           0.648406  0.530166

# %%
path = os.path.join(base_dir, 'setting2_retriever2.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting2_retriever2_005
# 0.5349116951254885
#                      index  faithfulness  answer_relevancy  \
# 0  setting2_retriever2_003      0.293561          0.573299
# 1  setting2_retriever2_005      0.652422          0.583937
# 2  setting2_retriever2_007      0.524107          0.377467
# 3  setting2_retriever2_010      0.656250          0.376830
#
#    answer_correctness  context_recall  context_precision      mean
# 0            0.354985            0.20           0.733333  0.431036
# 1            0.450422            0.30           0.687778  0.534912
# 2            0.363764            0.20           0.562746  0.405617
# 3            0.394017            0.25           0.595767  0.454573

# %%
path = os.path.join(base_dir, 'setting3_retriever3.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting3_retriever3_010_002
# 0.5036049465974524
#                           index  faithfulness  answer_relevancy  \
# 0   setting3_retriever3_003_001      0.401010          0.576248
# 1   setting3_retriever3_003_002      0.430556          0.473512
# 2   setting3_retriever3_003_003      0.614583          0.562394
# 3   setting3_retriever3_003_004      0.392857          0.570354
# 4   setting3_retriever3_003_005      0.357639          0.665215
# 5   setting3_retriever3_003_006      0.267857          0.386808
# 6   setting3_retriever3_003_007      0.291667          0.578055
# 7   setting3_retriever3_005_001      0.513117          0.289384
# 8   setting3_retriever3_005_002      0.398148          0.382564
# 9   setting3_retriever3_005_003      0.343750          0.290420
# 10  setting3_retriever3_005_004      0.279924          0.281101
# 11  setting3_retriever3_005_005      0.516667          0.484151
# 12  setting3_retriever3_005_006      0.400000          0.577602
# ...

# %%
path = os.path.join(base_dir, 'setting4_our_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting4_our_retriever_010_001
# 0.5585183239549183
#                              index  faithfulness  answer_relevancy  \
# 0   setting4_our_retriever_003_001      0.437500          0.670804
# 1   setting4_our_retriever_003_002      0.292361          0.470568
# 2   setting4_our_retriever_003_003      0.236111          0.663371
# 3   setting4_our_retriever_003_004      0.420940          0.480416
# 4   setting4_our_retriever_003_005      0.375000          0.382356
# 5   setting4_our_retriever_003_006      0.250000          0.572081
# 6   setting4_our_retriever_003_007      0.251667          0.571507
# 7   setting4_our_retriever_005_001      0.236111          0.482225
# 8   setting4_our_retriever_005_002      0.306111          0.565297
# 9   setting4_our_retriever_005_003      0.400000          0.568535
# 10  setting4_our_retriever_005_004      0.314815          0.583494
# 11  setting4_our_retriever_005_005      0.433333          0.764869
# ...

# %%
path = os.path.join(base_dir, 'setting5_mq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting5_mq_retriever
# 0.383645597928128
#                    index  faithfulness  answer_relevancy  answer_correctness  \
# 0  setting5_mq_retriever      0.256614          0.277711            0.413804
#
#    context_recall  context_precision      mean
# 0             0.3           0.670099  0.383646

# %%
path = os.path.join(base_dir, 'setting5_mq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
