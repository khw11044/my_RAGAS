# %%
import pandas as pd 
import ast
import nest_asyncio         # nest_asyncio는 파이썬의 비동기 코드 실행을 도와주는 패키지
nest_asyncio.apply()        # Jupyter 노트북과 같이 이벤트 루프가 이미 실행 중인 환경에서 비동기 코드를 여러 번 실행할 수 있도록 설정하는 데 사용
# 이거 안하면 무조건 에러남 
import os

# %%
base_dir = 'experiment_dataset/QA_results'

# %%
path = os.path.join(base_dir, 'setting1_retriever1.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting1_retriever1_005
# 0.770514769312424
#                      index  faithfulness  answer_relevancy  context_recall  \
# 0  setting1_retriever1_003      0.747147          0.767905        0.636364
# 1  setting1_retriever1_005      0.838312          0.834782        0.818182
# 2  setting1_retriever1_007      0.806006          0.752260        0.818182
# 3  setting1_retriever1_010      0.896620          0.809962        0.818182
#
#    context_precision  answer_correctness  answer_similarity      mean
# 0           0.636364            0.498669           0.943480  0.704988
# 1           0.661364            0.530282           0.940168  0.770515
# 2           0.660714            0.484692           0.948456  0.745052
# 3           0.631786            0.488367           0.944312  0.764871

# %%
path = os.path.join(base_dir, 'setting2_retriever2.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting2_retriever2_007
# 0.7834108568988
#                      index  faithfulness  answer_relevancy  context_recall  \
# 0  setting2_retriever2_003      0.840152          0.949337        0.727273
# 1  setting2_retriever2_005      0.845455          0.832989        0.818182
# 2  setting2_retriever2_007      0.790548          0.912493        0.818182
# 3  setting2_retriever2_010      0.831457          0.741315        0.818182
#
#    context_precision  answer_correctness  answer_similarity      mean
# 0           0.636364            0.501548           0.938901  0.765596
# 1           0.727273            0.527678           0.943289  0.782477
# 2           0.757576            0.484046           0.937619  0.783411
# 3           0.695455            0.485876           0.946969  0.753209

# %%
path = os.path.join(base_dir, 'setting3_retriever3.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting3_retriever3_005_005
# 0.8041346322521846
#                           index  faithfulness  answer_relevancy  \
# 0   setting3_retriever3_003_001      0.750541          0.771468
# 1   setting3_retriever3_003_002      0.742965          0.776203
# 2   setting3_retriever3_003_003      0.693182          0.778978
# 3   setting3_retriever3_003_004      0.740152          0.851985
# 4   setting3_retriever3_003_005      0.862662          0.931743
# 5   setting3_retriever3_003_006      0.876748          0.855674
# 6   setting3_retriever3_003_007      0.902273          0.859876
# 7   setting3_retriever3_005_001      0.742100          0.844257
# 8   setting3_retriever3_005_002      0.792249          0.846810
# 9   setting3_retriever3_005_003      0.814935          0.846413
# 10  setting3_retriever3_005_004      0.909307          0.747947
# 11  setting3_retriever3_005_005      0.906703          0.914888
# 12  setting3_retriever3_005_006      0.890152          0.904927
# 13  setting3_retriever3_005_007      0.828571          0.829687
# 14  setting3_retriever3_007_001      0.861616          0.644755
# 15  setting3_retriever3_007_002      0.812626          0.830305
# 16  setting3_retriever3_007_003      0.866667          0.811790
# 17  setting3_retriever3_007_004      0.780608          0.808260
# 18  setting3_retriever3_007_005      0.821488          0.724463
# 19  setting3_retriever3_007_006      0.829726          0.742531
# 20  setting3_retriever3_007_007      0.824897          0.742573
# 21  setting3_retriever3_010_001      0.928399          0.820946
# 22  setting3_retriever3_010_002      0.855808          0.733531
# 23  setting3_retriever3_010_003      0.966811          0.827662
# 24  setting3_retriever3_010_004      0.895960          0.899232
# 25  setting3_retriever3_010_005      0.898990          0.814381
# 26  setting3_retriever3_010_006      0.915152          0.724721
# 27  setting3_retriever3_010_007      0.899449          0.756772
#
#     context_recall  context_precision  answer_correctness  answer_similarity  \
# 0         0.545455           0.636364            0.357326           0.927871
# 1         0.545455           0.636364            0.416678           0.932985
# 2         0.545455           0.636364            0.353778           0.928692
# 3         0.545455           0.636364            0.376023           0.932862
# 4         0.727273           0.681818            0.446104           0.937783
# 5         0.818182           0.734848            0.533684           0.947573
# 6         0.727273           0.696970            0.511591           0.946348
# 7         0.772727           0.725000            0.415987           0.939952
# 8         0.727273           0.727273            0.463900           0.937497
# 9         0.818182           0.727273            0.420600           0.937960
# 10        0.818182           0.727273            0.464104           0.937085
# 11        0.818182           0.727273            0.517715           0.940046
# 12        0.818182           0.719697            0.472341           0.936582
# 13        0.818182           0.712121            0.492555           0.935570
# 14        0.818182           0.707576            0.454185           0.945931
# 15        0.818182           0.734848            0.402741           0.943739
# 16        0.818182           0.734848            0.518767           0.941361
# 17        0.818182           0.757576            0.448930           0.941717
# 18        0.818182           0.712121            0.471751           0.945215
# 19        0.818182           0.707576            0.500404           0.942481
# 20        0.818182           0.715909            0.493276           0.947216
# 21        0.818182           0.725253            0.473427           0.948998
# 22        0.818182           0.725253            0.508217           0.950265
# 23        0.818182           0.718182            0.523768           0.950762
# 24        0.818182           0.680303            0.486526           0.942424
# 25        0.818182           0.657576            0.544486           0.948596
# 26        0.818182           0.690368            0.464439           0.943351
# 27        0.818182           0.700108            0.508146           0.944391
#
#         mean
# 0   0.664837
# 1   0.675108
# 2   0.656075
# 3   0.680473
# 4   0.764564
# 5   0.794452
# 6   0.774055
# 7   0.740004
# 8   0.749167
# 9   0.760894
# 10  0.767316
# 11  0.804135
# 12  0.790314
# 13  0.769448
# 14  0.738707
# 15  0.757074
# 16  0.781936
# 17  0.759212
# 18  0.748870
# 19  0.756817
# 20  0.757009
# 21  0.785867
# 22  0.765209
# 23  0.800894
# 24  0.787104
# 25  0.780369
# 26  0.759369
# 27  0.771175

# %%
path = os.path.join(base_dir, 'setting4_our_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting4_our_retriever_005_004
# 0.7842925342262249
#                              index  faithfulness  answer_relevancy  \
# 0   setting4_our_retriever_003_001      0.818182          0.771211
# 1   setting4_our_retriever_003_002      0.798485          0.772628
# 2   setting4_our_retriever_003_003      0.767857          0.777435
# 3   setting4_our_retriever_003_004      0.718509          0.766735
# 4   setting4_our_retriever_003_005      0.742424          0.764336
# 5   setting4_our_retriever_003_006      0.771645          0.758587
# 6   setting4_our_retriever_003_007      0.719697          0.766640
# 7   setting4_our_retriever_005_001      0.878788          0.839790
# 8   setting4_our_retriever_005_002      0.838843          0.831976
# 9   setting4_our_retriever_005_003      0.879371          0.830919
# 10  setting4_our_retriever_005_004      0.905770          0.831613
# 11  setting4_our_retriever_005_005      0.840909          0.832140
# 12  setting4_our_retriever_005_006      0.882395          0.838783
# 13  setting4_our_retriever_005_007      0.756394          0.831360
# 14  setting4_our_retriever_007_001      0.850069          0.836663
# 15  setting4_our_retriever_007_002      0.860136          0.850970
# 16  setting4_our_retriever_007_003      0.777345          0.847381
# 17  setting4_our_retriever_007_004      0.803030          0.741455
# 18  setting4_our_retriever_007_005      0.842090          0.816255
# 19  setting4_our_retriever_007_006      0.877165          0.811606
# 20  setting4_our_retriever_007_007      0.882576          0.825846
# 21  setting4_our_retriever_010_001      0.789773          0.815231
# 22  setting4_our_retriever_010_002      0.847488          0.727980
# 23  setting4_our_retriever_010_003      0.797203          0.810881
# 24  setting4_our_retriever_010_004      0.856269          0.726470
# 25  setting4_our_retriever_010_005      0.823465          0.729692
# 26  setting4_our_retriever_010_006      0.829293          0.724107
# 27  setting4_our_retriever_010_007      0.790355          0.814411
#
#     context_recall  context_precision  answer_correctness  answer_similarity  \
# 0         0.636364           0.636364            0.509174           0.943704
# 1         0.636364           0.636364            0.503659           0.941787
# 2         0.636364           0.636364            0.536740           0.941748
# 3         0.636364           0.598485            0.507967           0.940310
# 4         0.636364           0.636364            0.541855           0.942361
# 5         0.636364           0.636364            0.561304           0.944447
# 6         0.636364           0.636364            0.457627           0.940074
# 7         0.818182           0.623485            0.511971           0.945302
# 8         0.818182           0.656818            0.552975           0.951146
# 9         0.818182           0.623990            0.561902           0.951106
# 10        0.818182           0.661364            0.546067           0.942759
# 11        0.818182           0.623990            0.440377           0.941995
# 12        0.727273           0.661364            0.557158           0.950960
# 13        0.818182           0.661364            0.479147           0.940838
# 14        0.818182           0.660714            0.484369           0.944915
# 15        0.818182           0.665260            0.499995           0.949618
# 16        0.818182           0.631786            0.456379           0.945635
# 17        0.818182           0.672330            0.433541           0.944725
# 18        0.818182           0.665260            0.518309           0.943694
# 19        0.818182           0.660714            0.495834           0.944034
# 20        0.818182           0.665260            0.480715           0.946000
# 21        0.818182           0.634452            0.494624           0.941459
# 22        0.818182           0.634452            0.484550           0.945992
# 23        0.818182           0.627381            0.479423           0.940351
# 24        0.818182           0.660714            0.491159           0.943141
# 25        0.818182           0.627381            0.487661           0.943551
# 26        0.818182           0.634957            0.517094           0.947165
# 27        0.818182           0.660714            0.514496           0.948045
#
#         mean
# 0   0.719166
# 1   0.714881
# 2   0.716085
# 3   0.694728
# 4   0.710617
# 5   0.718118
# 6   0.692794
# 7   0.769586
# 8   0.774990
# 9   0.777578
# 10  0.784293
# 11  0.749599
# 12  0.769655
# 13  0.747881
# 14  0.765819
# 15  0.774027
# 16  0.746118
# 17  0.735544
# 18  0.767298
# 19  0.767922
# 20  0.769763
# 21  0.748953
# 22  0.743107
# 23  0.745570
# 24  0.749322
# 25  0.738322
# 26  0.745133
# 27  0.757701

# %%
path = os.path.join(base_dir, 'setting5_mq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting5_mq_retriever_002
# 0.7649620494912908
#                        index  faithfulness  answer_relevancy  context_recall  \
# 0      setting5_mq_retriever      0.897619          0.817189        0.818182
# 1  setting5_mq_retriever_000      0.956061          0.813061        0.727273
# 2  setting5_mq_retriever_001      0.809877          0.717175        0.818182
# 3  setting5_mq_retriever_002      0.855051          0.831058        0.818182
# 4  setting5_mq_retriever_003      0.878896          0.827737        0.818182
#
#    context_precision  answer_correctness  answer_similarity      mean
# 0           0.562987            0.538979           0.945551  0.763418
# 1           0.573485            0.503129           0.938030  0.751840
# 2           0.580303            0.462504           0.945321  0.722227
# 3           0.575758            0.564834           0.944891  0.764962
# 4           0.558442            0.557697           0.947701  0.764776

# %%
path = os.path.join(base_dir, 'setting6_sq_retriever.xlsx')

# make_corpus.py 파일로 만듬 : SimpleDirectoryReader와 TokenTextSplitter로 자른 내용을 넣음 
df = pd.read_excel(path)

max_mean_index = df.loc[df['mean'].idxmax(), 'index']

print(max_mean_index)
print(df['mean'].max())


df
# Out:
# setting6_sq_retriever
# 0.3987447051325312
#                    index  faithfulness  answer_relevancy  context_recall  \
# 0  setting6_sq_retriever      0.258532          0.553217             0.1
#
#    context_precision  answer_correctness  answer_similarity      mean
# 0              0.225            0.347728           0.907992  0.398745
